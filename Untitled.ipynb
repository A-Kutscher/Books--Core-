# %%
# !pip install pandas mysql-connector-python
# Out:
# Requirement already satisfied: pandas in c:\users\amber\anaconda3\envs\dojo-env\lib\site-packages (1.5.3)
# Requirement already satisfied: mysql-connector-python in c:\users\amber\anaconda3\envs\dojo-env\lib\site-packages (8.1.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\amber\anaconda3\envs\dojo-env\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\amber\anaconda3\envs\dojo-env\lib\site-packages (from pandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\amber\anaconda3\envs\dojo-env\lib\site-packages (from pandas) (1.23.4)
# Requirement already satisfied: protobuf<=4.21.12,>=4.21.1 in c:\users\amber\anaconda3\envs\dojo-env\lib\site-packages (from mysql-connector-python) (4.21.12)
# Requirement already satisfied: six>=1.5 in c:\users\amber\anaconda3\envs\dojo-env\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
import pandas as pd
from sqlalchemy import create_engine, inspect
from sqlalchemy_utils import database_exists, create_database
import pymysql
pymysql.install_as_MySQLdb()
from urllib.parse import quote_plus as urlquote

# %%
import json
with open(r"C:\Users\amber\.secret\mysql.json") as f:
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['username', 'password'])

# %%
# Extract the username, password, and database name
username = login["username"]
password = login["password"]
database_name = "books"

# %%
connection = f"mysql+pymysql://{username}:{password}@localhost/books"
engine = create_engine(connection)

# %%
# Check if the database exists; if not, create it
if not database_exists(engine.url):
    create_database(engine.url)

# %%
create_database(connection)

# %%
database_exists(connection)
# Out:
# True

# %%
# Check if the database exists. If not, create it.
if database_exists(connection) == False:
  create_database(connection)
else:
  print('The database already exists')
# Out:
# The database already exists

# %%
import glob
q = "Data/data (*).csv"
chunked_files = glob.glob(q)
# Showing the first 5
chunked_files[:5]
# Out:
# ['Data\\data (authors).csv',
#  'Data\\data (books).csv',
#  'Data\\data (favorites).csv',
#  'Data\\data (users).csv']

# %%
# Loading all files as df and appending to a list
df_list = []
for file in chunked_files:
    temp_df = pd.read_csv(file, index_col=0)
    df_list.append(temp_df)

# Concatenating the list of dfs into 1 combined
df_combined = pd.concat(df_list)
df_combined
# Out:
#          author_name                 title  author_id  book_id first_name  \
# 1       Stephen King                   NaN        NaN      NaN        NaN
# 2  F.Scott Fitgerald                   NaN        NaN      NaN        NaN
# 3        Jack London                   NaN        NaN      NaN        NaN
# 4        Jane Austen                   NaN        NaN      NaN        NaN
# 5       Mary Shelley                   NaN        NaN      NaN        NaN
# 1                NaN           The Shining        1.0      NaN        NaN
# 2                NaN                    It        1.0      NaN        NaN
# 3                NaN      The Great Gatsby        2.0      NaN        NaN
# 4                NaN  The Call of the Wild        3.0      NaN        NaN
# 5                NaN   Pride and Prejudice        4.0      NaN        NaN
# 6                NaN          Frankenstein        5.0      NaN        NaN
# 1                NaN                   NaN        NaN      1.0        NaN
# 1                NaN                   NaN        NaN      2.0        NaN
# 1                NaN                   NaN        NaN      3.0        NaN
# 2                NaN                   NaN        NaN      4.0        NaN
# 2                NaN                   NaN        NaN      5.0        NaN
# 3                NaN                   NaN        NaN      5.0        NaN
# 3                NaN                   NaN        NaN      6.0        NaN
# 1                NaN                   NaN        NaN      NaN       John
# 2                NaN                   NaN        NaN      NaN      Robin
# 3                NaN                   NaN        NaN      NaN     Gloria
#
#    last_name                 email
# 1        NaN                   NaN
# 2        NaN                   NaN
# 3        NaN                   NaN
# 4        NaN                   NaN
# 5        NaN                   NaN
# 1        NaN                   NaN
# 2        NaN                   NaN
# 3        NaN                   NaN
# 4        NaN                   NaN
# 5        NaN                   NaN
# 6        NaN                   NaN
# 1        NaN                   NaN
# 1        NaN                   NaN
# 1        NaN                   NaN
# 2        NaN                   NaN
# 2        NaN                   NaN
# 3        NaN                   NaN
# 3        NaN                   NaN
# 1        Doe          JD@books.com
# 2      Smith       Robin@books.com
# 3  Rodriguez  grodriquez@books.com

# %%
# Saving the final combined dataframe
final_fname ='Data/data_combined.csv.gz'
df_combined.to_csv(final_fname, compression='gzip', index=False)

# %%
df_combineD = pd.read_csv(final_fname)
df_combined
# Out:
#          author_name                 title  author_id  book_id first_name  \
# 1       Stephen King                   NaN        NaN      NaN        NaN
# 2  F.Scott Fitgerald                   NaN        NaN      NaN        NaN
# 3        Jack London                   NaN        NaN      NaN        NaN
# 4        Jane Austen                   NaN        NaN      NaN        NaN
# 5       Mary Shelley                   NaN        NaN      NaN        NaN
# 1                NaN           The Shining        1.0      NaN        NaN
# 2                NaN                    It        1.0      NaN        NaN
# 3                NaN      The Great Gatsby        2.0      NaN        NaN
# 4                NaN  The Call of the Wild        3.0      NaN        NaN
# 5                NaN   Pride and Prejudice        4.0      NaN        NaN
# 6                NaN          Frankenstein        5.0      NaN        NaN
# 1                NaN                   NaN        NaN      1.0        NaN
# 1                NaN                   NaN        NaN      2.0        NaN
# 1                NaN                   NaN        NaN      3.0        NaN
# 2                NaN                   NaN        NaN      4.0        NaN
# 2                NaN                   NaN        NaN      5.0        NaN
# 3                NaN                   NaN        NaN      5.0        NaN
# 3                NaN                   NaN        NaN      6.0        NaN
# 1                NaN                   NaN        NaN      NaN       John
# 2                NaN                   NaN        NaN      NaN      Robin
# 3                NaN                   NaN        NaN      NaN     Gloria
#
#    last_name                 email
# 1        NaN                   NaN
# 2        NaN                   NaN
# 3        NaN                   NaN
# 4        NaN                   NaN
# 5        NaN                   NaN
# 1        NaN                   NaN
# 2        NaN                   NaN
# 3        NaN                   NaN
# 4        NaN                   NaN
# 5        NaN                   NaN
# 6        NaN                   NaN
# 1        NaN                   NaN
# 1        NaN                   NaN
# 1        NaN                   NaN
# 2        NaN                   NaN
# 2        NaN                   NaN
# 3        NaN                   NaN
# 3        NaN                   NaN
# 1        Doe          JD@books.com
# 2      Smith       Robin@books.com
# 3  Rodriguez  grodriquez@books.com

# %%
df = pd.read_csv('Data/data_combined.csv.gz')
df.head()
# Out:
#          author_name title  author_id  book_id first_name last_name email
# 0       Stephen King   NaN        NaN      NaN        NaN       NaN   NaN
# 1  F.Scott Fitgerald   NaN        NaN      NaN        NaN       NaN   NaN
# 2        Jack London   NaN        NaN      NaN        NaN       NaN   NaN
# 3        Jane Austen   NaN        NaN      NaN        NaN       NaN   NaN
# 4       Mary Shelley   NaN        NaN      NaN        NaN       NaN   NaN

# %%
df.to_sql('books', engine, if_exists = 'replace')
# Out:
# 21

# %%
query = """SELECT * FROM books LIMIT 5;"""pd.read_sql(q, engine)
    
    # Display the table name and data
    print(f"Table Name: {table_name}")
    print(df)
    print("\n")  # Add a separator between tables
